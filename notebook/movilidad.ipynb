# %%
import pandas as pd
import numpy as np
import sys
import re

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_movilidad = pd.read_csv(r"C:\Users\mituc\Ironhack\Curso\IronLabs\Proyecto-1\data\2020_ES_Region_Mobility_Report.csv", sep=',', encoding='latin-1', index_col = 0)

# %%
df_movilidad.head(5)
# Out:
#                     country_region sub_region_1 sub_region_2  metro_area  \
# country_region_code
# ES                           Spain          NaN          NaN         NaN
# ES                           Spain          NaN          NaN         NaN
# ES                           Spain          NaN          NaN         NaN
# ES                           Spain          NaN          NaN         NaN
# ES                           Spain          NaN          NaN         NaN
#
#                     iso_3166_2_code  census_fips_code  \
# country_region_code
# ES                              NaN               NaN
# ES                              NaN               NaN
# ES                              NaN               NaN
# ES                              NaN               NaN
# ES                              NaN               NaN
#
#                                         place_id        date  \
# country_region_code
# ES                   ChIJi7xhMnjjQgwR7KNoB5Qs7KY  2020-02-15
# ...

# %%
df_movilidad_b = df_movilidad[df_movilidad['sub_region_2'].str.contains('Barcelona') == True]

# %%
#df_movilidad_b = df_movilidad[df_movilidad['region'].str.contains('Barcelona') == True]

# %%
df_movilidad_b.describe()
# Out:
#        metro_area  census_fips_code  \
# count         0.0               0.0
# mean          NaN               NaN
# std           NaN               NaN
# min           NaN               NaN
# 25%           NaN               NaN
# 50%           NaN               NaN
# 75%           NaN               NaN
# max           NaN               NaN
#
#        retail_and_recreation_percent_change_from_baseline  \
# count                                         321.000000
# mean                                          -43.769470
# std                                            26.758231
# min                                           -97.000000
# 25%                                           -64.000000
# 50%                                           -38.000000
# 75%                                           -24.000000
# max                                             1.000000
#
#        grocery_and_pharmacy_percent_change_from_baseline  \
# ...

# %%
df_movilidad_b.head(3)
# Out:
#                     country_region sub_region_1 sub_region_2  metro_area  \
# country_region_code
# ES                           Spain    Catalonia    Barcelona         NaN
# ES                           Spain    Catalonia    Barcelona         NaN
# ES                           Spain    Catalonia    Barcelona         NaN
#
#                     iso_3166_2_code  census_fips_code  \
# country_region_code
# ES                             ES-B               NaN
# ES                             ES-B               NaN
# ES                             ES-B               NaN
#
#                                         place_id        date  \
# country_region_code
# ES                   ChIJZb1_yQvmpBIRsMmjIeD6AAM  2020-02-15
# ES                   ChIJZb1_yQvmpBIRsMmjIeD6AAM  2020-02-16
# ES                   ChIJZb1_yQvmpBIRsMmjIeD6AAM  2020-02-17
#
#                      retail_and_recreation_percent_change_from_baseline  \
# country_region_code
# ...

# %%
df_movilidad_b['place_id'].unique()
# Out:
# array(['ChIJZb1_yQvmpBIRsMmjIeD6AAM'], dtype=object)

# %%
with open('output1.txt', encoding="utf8") as f:
    lines = f.readlines()

# %%
print(type(lines))
# Out:
# <class 'list'>
